# %% [markdown]
# # 📘 Module 4 Quiz – Functions & Error Handling
# ### Complete the missing parts of the code before checking the solutions at the end! 🚀

# %% [markdown]
# ## 📌 Q1: Recursive Function – Factorial Calculation
# 🎯 **Problem Statement:** Write a recursive function `factorial(n)` that returns the **factorial** of a number.
#
# 👉 **Example:**
# ```python
# print(factorial(5))
# ```
# 🔹 **Expected Output:** `120`

# %%
def factorial(n):
    # Your code here
    pass

# Test the function
print(factorial(5))

# %% [markdown]
# ## 📌 Q2: Function with Multiple Parameters – String Formatting
# 🎯 **Problem Statement:** Write a function `format_string(name, age, city)` that takes a **name**, **age**, and **city** as arguments and returns a formatted string.
#
# 👉 **Example:**
# ```python
# print(format_string("Alice", 25, "New York"))
# ```
# 🔹 **Expected Output:** `Alice is 25 years old and lives in New York.`

# %%
def format_string(name, age, city):
    # Your code here
    pass

# Test the function
print(format_string("Alice", 25, "New York"))

# %% [markdown]
# ## 📌 Q3: Using Lambda – Sort a List of Tuples
# 🎯 **Problem Statement:** Write a lambda function to **sort** the list in **descending order of scores**.
#
# 👉 **Example:**
# ```python
# students = [("Alice", 85), ("Bob", 92), ("Charlie", 78)]
# sorted_students = # Complete this part
# print(sorted_students)
# ```
# 🔹 **Expected Output:** `[("Bob", 92), ("Alice", 85), ("Charlie", 78)]`

# %%
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78)]
sorted_students = # Your code here
print(sorted_students)

# %% [markdown]
# ## 📌 Q4: Handling Multiple Exceptions
# 🎯 **Problem Statement:** Write a function `safe_divide(a, b)` that performs **division** but handles:
# ✅ **ZeroDivisionError** (if `b` is zero)
# ✅ **TypeError** (if non-numeric inputs are given)
#
# 👉 **Example:**
# ```python
# print(safe_divide(10, 2))
# print(safe_divide(10, 0))
# print(safe_divide(10, "a"))
# ```
# 🔹 **Expected Output:**
# ```
# 5.0
# Error: Cannot divide by zero!
# Error: Invalid input type!
# ```

# %%
def safe_divide(a, b):
    # Your code here
    pass

# Test the function
print(safe_divide(10, 2))
print(safe_divide(10, 0))
print(safe_divide(10, "a"))

# %% [markdown]
# ## 📌 Q5: Nested Functions – Generate a Power Function
# 🎯 **Problem Statement:** Write a function `power_function(n)` that **returns** another function.
#
# 👉 **Example:**
# ```python
# square = power_function(2)
# print(square(4))
# cube = power_function(3)
# print(cube(2))
# ```
# 🔹 **Expected Output:**
# ```
# 16
# 8
# ```

# %%
def power_function(n):
    # Your code here
    pass

# Test the function
square = power_function(2)
print(square(4))
cube = power_function(3)
print(cube(2))

# %% [markdown]
# # 🏆 **Answers**
# Scroll back up and complete the missing parts before checking the answers!

# %%
# Q1 Answer
def factorial(n):
    return 1 if n == 0 else n * factorial(n - 1)

# Q2 Answer
def format_string(name, age, city):
    return f"{name} is {age} years old and lives in {city}."

# Q3 Answer
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78)]
sorted_students = sorted(students, key=lambda x: x[1], reverse=True)

# Q4 Answer
def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "Error: Cannot divide by zero!"
    except TypeError:
        return "Error: Invalid input type!"

# Q5 Answer
def power_function(n):
    return lambda x: x ** n

# %% [markdown]
# # Python Basics - Variables, Data Types & User Input
# ## Quiz (Fill in the missing parts)

# %%
# Q1: Find the Data Type (Using type Function)
value = input("Enter any value: ")
# Complete the following line to print the data type
# print(...)

# %%
# Q2: Swap Two Variables Without Using a Third Variable
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
# Swap the values without using a third variable
# a, b = ...
print("After swapping: a =", a, "b =", b)

# %%
# Q3: Sum of Digits
num = input("Enter a two-digit number: ")
# Compute the sum of digits here
# sum_digits = ...
print("Sum of digits:", sum_digits)

# %%
# Q4: Check for Data Type Before Conversion
value = input("Enter a number: ")
# Check if value is a number before converting
# if ...:
#     num = int(value)
#     print("Converted to integer:", num)
# else:
#     print("Not a valid number!")

# %%
# Q5: Reverse a String Input
name = input("Enter your name: ")
# Reverse the string
# print("Reversed name:", ...)

# %%
# Q6: Find ASCII Value of a Character
char = input("Enter a character: ")
# Print ASCII value
# print("ASCII Value:", ...)

# %%
# Q7: Convert Celsius to Fahrenheit
celsius = float(input("Enter temperature in Celsius: "))
# Convert to Fahrenheit
# fahrenheit = ...
print("Temperature in Fahrenheit:", fahrenheit)

# %%
# Q8: Boolean Logic Challenge
q1 = input("Do you like Python? (True/False): ").strip().capitalize() == "True"
q2 = input("Do you enjoy coding? (True/False): ").strip().capitalize() == "True"
# Check if both are true
# print("Both answers are True:", ...)

# %%
# Q9: Find the Largest of Three Numbers
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
# Find largest number
# largest = ...
print("The largest number is:", largest)

# %%
# Q10: Convert String to Title Case
text = input("Enter a sentence: ")
# Convert to title case
# print("Title Case:", ...)

# %%
# Q11: Check if Input is a Palindrome
word = input("Enter a word: ").lower()
# Check for palindrome
# if ...:
#     print("It is a palindrome!")
# else:
#     print("Not a palindrome.")

# %% [markdown]
# ## ANSWERS SECTION
# Uncomment the below lines to reveal full solutions:

# %%
# print("Q1: print(type(value))")
# print("Q2: a, b = b, a")
# print("Q3: sum_digits = int(num[0]) + int(num[1])")
# print("Q4: if value.isdigit(): num = int(value)")
# print("Q5: print(name[::-1])")
# print("Q6: print(ord(char))")
# print("Q7: fahrenheit = (celsius * 9/5) + 32")
# print("Q8: print(q1 and q2)")
# print("Q9: largest = max(a, b, c)")
# print("Q10: print(text.title())")
# print("Q11: if word == word[::-1]: print(\"It is a palindrome!\") else: print(\"Not a palindrome.\")")

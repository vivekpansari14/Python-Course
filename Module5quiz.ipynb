# %% [markdown]
# # Module 5 Quiz: Data Structures in Python
#
# This notebook contains 5-7 challenging coding problems related to lists, tuples, dictionaries, and sets.
# Fill in the missing parts of the code to complete the solutions. The answers are provided at the end of the notebook.

# %%
# Question 1: List Manipulation
# Complete the function to return a list with unique elements sorted in descending order.
def unique_sorted_desc(lst):
    return sorted(set(lst), __________)  # Fill in the missing argument

# Test Case
print(unique_sorted_desc([4, 2, 8, 5, 2, 4, 8, 1]))  # Expected Output: [8, 5, 4, 2, 1]

# %%
# Question 2: Tuple Indexing
# Given a tuple of numbers, return the element at the second index.
def get_second_element(tpl):
    return __________  # Fill in the missing code

# Test Case
test_tuple = (10, 20, 30, 40)
print(get_second_element(test_tuple))  # Expected Output: 30

# %%
# Question 3: Dictionary Key Lookup
# Complete the function to return the capital of a given country from the dictionary.
def get_capital(country, capitals):
    return capitals.__________(country, "Capital not found")  # Fill in the missing method

# Test Case
capitals_dict = {"India": "New Delhi", "USA": "Washington D.C.", "France": "Paris"}
print(get_capital("USA", capitals_dict))  # Expected Output: Washington D.C.
print(get_capital("Germany", capitals_dict))  # Expected Output: Capital not found

# %%
# Question 4: Set Operations
# Given two sets, return their union and intersection.
def set_operations(set1, set2):
    union_result = set1.__________(set2)  # Fill in the missing method
    intersection_result = set1.__________(set2)  # Fill in the missing method
    return union_result, intersection_result

# Test Case
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}
print(set_operations(set_a, set_b))  # Expected Output: ({1, 2, 3, 4, 5, 6}, {3, 4})

# %%
# Question 5: List Filtering
# Given a list of words, return a new list containing words that start with 'P'.
def filter_p_words(words):
    return [word for word in words if __________]  # Fill in the missing condition

# Test Case
word_list = ["Python", "Java", "PHP", "C++", "Perl"]
print(filter_p_words(word_list))  # Expected Output: ['Python', 'PHP', 'Perl']

# %%
# Question 6: Dictionary Comprehension
# Given a list of numbers, create a dictionary where each number is a key and its square is the value.
def square_dict(numbers):
    return {num: __________ for num in numbers}  # Fill in the missing expression

# Test Case
print(square_dict([1, 2, 3, 4]))  # Expected Output: {1: 1, 2: 4, 3: 9, 4: 16}

# %%
# Question 7: Removing Duplicates from List
# Given a list with duplicates, return a new list with duplicates removed while maintaining order.
def remove_duplicates(lst):
    seen = set()
    return [x for x in lst if not (x in seen or seen.__________(x))]  # Fill in the missing method

# Test Case
print(remove_duplicates([1, 2, 2, 3, 4, 4, 5]))  # Expected Output: [1, 2, 3, 4, 5]

# %% [markdown]
# ## Answers Section
#
# 1. `sorted(set(lst), reverse=True)`
# 2. `tpl[2]`
# 3. `capitals.get(country, "Capital not found")`
# 4. `set1.union(set2), set1.intersection(set2)`
# 5. `word.startswith('P')`
# 6. `num ** 2`
# 7. `seen.add(x)`
